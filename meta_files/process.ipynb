# %%
import json
from omegaconf import OmegaConf

with open("new_playtable.json", "r") as f:
    d = json.load(f)
d_v = OmegaConf.load("new_playtable_validation.yaml")
Text2ID = {}
for idx, value in enumerate(d.values()):
    for i in value:
        Text2ID[i] = idx

with open("Task2ID.json", "w") as f:
    json.dump(Text2ID, f)

# %%
import torch
torch.tensor([1,2,3,4], dtype=torch.int64)
# Out:
# tensor([1, 2, 3, 4])
